# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 6 launch
data_path = '/home/specialo0/notebooks/data/uchebnoe/cv_kalinych/dataset_fullpath.yaml'

model = YOLO("/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/runs/detect/yolov8n_sign_destroyer_5launch/weights/last.pt").to('cuda')

model.train(data = data_path,
            epochs = 10,
            batch = 5,
            name='yolov8n_sign_destroyer_6launch',
            amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.221 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
# 5 launch
data_path = '/home/specialo0/notebooks/data/uchebnoe/cv_kalinych/dataset_fullpath.yaml'

model = YOLO("/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/runs/detect/yolov8n_sign_destroyer_4launch/weights/last.pt").to('cuda')

model.train(data = data_path,
            epochs = 11,
            batch = 5,
            name='yolov8n_sign_destroyer_5launch',
            amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.220 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
# 4 launch
data_path = '/home/specialo0/notebooks/data/uchebnoe/cv_kalinych/dataset_fullpath.yaml'

model = YOLO("/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/runs/detect/yolov8n_sign_destroyer_3launch/weights/last.pt").to('cuda')

model.train(data = data_path,
            epochs = 1,
            batch = 5,
            name='yolov8n_sign_destroyer_4launch',
            amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.220 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
# 3 launch
data_path = '/home/specialo0/notebooks/data/uchebnoe/cv_kalinych/dataset_fullpath.yaml'

model = YOLO("/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/runs/detect/yolov8n_sign_destroyer3/weights/last.pt").to('cuda')

model.train(data = data_path,
            epochs = 10,
            batch = 5,
            name='yolov8n_sign_destroyer',
            amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.219 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
# 2 launch
data_path = '/home/specialo0/notebooks/data/uchebnoe/cv_kalinych/dataset_fullpath.yaml'

model = YOLO("/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/runs/detect/yolov8n_sign_destroyer2/weights/last.pt").to('cuda')

model.train(data = data_path,
            epochs = 10,
            batch = 5,
            name='yolov8n_sign_destroyer',
            amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.219 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
# 1 launch
data_path = '/home/specialo0/notebooks/data/uchebnoe/cv_kalinych/dataset_fullpath.yaml'

model = YOLO('yolov8n.pt').to('cuda')

model.train(data = data_path,
            epochs = 5,
            batch = 5,
            name='yolov8n_sign_destroyer',
            amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.219 available 😃 Update with 'pip install -U ultralytics'
# ...

# %% [markdown]
# ## Test

# %%
model = YOLO('/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/runs/detect/yolov8n_sign_destroyer/weights/best.pt').to('cuda')
results = model.predict(source='/home/specialo0/notebooks/uchебновое/cv_Калиныч_2/sign detection/autosave01_02_2012_09_13_49.jpg')
